# %% [markdown]
# Este notebook fue hecho por [@silvercorp](https://www.twitter.com/silvercorp) en el Meetup de Data Science de Platzi

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
import tweepy 
import pandas as pd
import csv
from google.colab import drive

# %%
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
#Tus credenciales consumer_key, consumer_secret, token_key, token_secret
consumer_key = ''
consumer_secret = ''
access_token_key = ''
access_token_secret = ''

# %%
def api_connection():
  auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  auth.set_access_token(access_token_key, access_token_secret)
  api = tweepy.API(auth, wait_on_rate_limit=True)

  try:
    api.verify_credentials()
    print('Auth Ok!')
  except Exception:
    print('Error!')
  
  return api

api = api_connection()
# Out:
# Auth Ok!

# %%
def extract_tweets(hashtag, count):
  api = api_connection()
  tweets = []
  for tweet in tweepy.Cursor(api.search, q=hashtag, lang='en', include_rts=False).items(count):
    if (not tweet.retweeted and 'RT @' not in tweet.text):
      tweets.append(tweet.text)
      #avatar, localización, verificada, hashtag, user_name, user_id, tweets.entities (url, imagenes, etc), source (android, web, ios)
      #source (android, web, ios) = @mercadito. ios = positivo,negativo,neutro. android=p,n,n.
  return tweets

# %%
print('Extracting Tweets...')
tweets = extract_tweets('@POTUS', 200)
df = pd.DataFrame(data=tweets, columns=['text'])
path = f'drive/My Drive/tweet_ext/tweets_potus.csv'
df.to_csv(path, sep=',', index=False)
# Out:
# Extracting Tweets...
# Auth Ok!

# %%
path = f'drive/My Drive/tweet_ext/tweets_potus.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                                                 text
# 0  Just testing how long Twitter police will allo...
# 1  @califhomes @POTUS @realDonaldTrump @KamalaHar...
# 2  @waltman00948696 @jackiebobacki @MeidasTouch @...
# 3  @ccaspen @POTUS We American taxpayers are fund...
# 4  @realDonaldTrump @POTUS u r are fraud. And we ...

# %%
import nltk as nltk
import re
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def transform(text):
  stopWords = set(stopwords.words('english'))
  text = str(text)
  text = re.sub(r'@[A-Za-z0-9]+', ' ', text) # Remover menciones @platzi 
  text = re.sub(r'RT[\s]', ' ', text) # Remover RTs
  text = re.sub(r'#', ' ', text) # Remover # en el tweet
  text = re.sub(r'https?:\/\/\S+', ' ', text) #Remover links

  words = text.lower().split()

  re_punc = re.compile('[%s]' % re.escape(string.punctuation))
  stripped = [re_punc.sub('', w) for w in words]
  no_garbage = [w for w in stripped if not w in stopWords]

  return (" ".join(no_garbage))

# %%
df['tweets_transform'] = df['text'].apply(transform)

# %%
df['tweets_transform'].head()
# Out:
# 0    testing long twitter police allow fact stateme...
# 1         lt pres trump generous offered quidprojoe a…
# 2                     guess missed joke wasnt good bu…
# 3    american taxpayers funding army lawyers trump ...
# 4    u r fraud see im teacher mom wife voter i’m wh...
# Name: tweets_transform, dtype: object

# %%
from textblob import TextBlob
def set_Sentiment(text):
  text = str(text)
  if text != '':
    analysis = TextBlob(text)
    if analysis.detect_language() == 'en':
      #analysis = analysis.translate(from_lang='es', to='en').sentiment
      analysis = analysis.sentiment
      sentiment = analysis.polarity
      return sentiment

# %%
df['polarity'] = df['tweets_transform'].apply(set_Sentiment)

# %%
df['polarity'].head() #-1 más negatividad, 1 más positiva
# Out:
# 0   -0.05
# 1    0.00
# 2    0.70
# 3    0.10
# 4    0.10
# Name: polarity, dtype: float64

# %%
df.describe()
# Out:
#         polarity
# count  64.000000
# mean    0.076166
# std     0.276178
# min    -0.800000
# 25%     0.000000
# 50%     0.000000
# 75%     0.125000
# max     1.000000

# %%
df['text'][1]
# Out:
# '@califhomes @POTUS @realDonaldTrump @KamalaHarris &lt;= Pres #Trump is very generous, so has he offered #QuidProJoe a… https://t.co/l4yOFE1ovJ'

# %%
#WordCloud

from wordcloud import WordCloud

text = df.tweets_transform
text.head()
# Out:
# 0    testing long twitter police allow fact stateme...
# 1         lt pres trump generous offered quidprojoe a…
# 2                     guess missed joke wasnt good bu…
# 3    american taxpayers funding army lawyers trump ...
# 4    u r fraud see im teacher mom wife voter i’m wh...
# Name: tweets_transform, dtype: object

# %%
text = ' '.join(df.tweets_transform)
text
# Out:
# 'testing long twitter police allow fact statement representative deleted… lt pres trump generous offered quidprojoe a… guess missed joke wasnt good bu… american taxpayers funding army lawyers trump amp gopers use legally workaround any… u r fraud see im teacher mom wife voter i’m white whole f… doesn’t surprise notion propriety lost reason personal vandeta that’s works vendetta tiktok… im pretty sure get another lawsuit youre smart en… 2 wake ❗️ dad trump mumbled would end payroll taxes fund social security se… added worries “bruh” end believable potus blown chances november payroll tax holiday means paying do… i’d rather chew arm lol fine dandy get extra 400 month probably good lu… don’t think americans fully internalized lasting damage done prevent talent immigrati… doesn’t father ask deferment joe biden question joeyasthma love thanks trump rock didn’t sham sham master pssst it’s press conference it’s campaign rally thank best president ever nancy one struggling stooges else creataest  taygeta … vote vote  youre judging eyes ears honest… bullshit gop willing negotiate bill provid… hates veterans choice thx birx oh please please please goto court  ace special prosecutor o… even was… 😷💔🇺🇸why think mark meadows showed stopping could sharpie another illegal executive…   china’s entry iran willaccessweapons systemsflowing… possible help going provide unemployed people  please explain love well made video someone would necessarily need iq lower gumboot relax irenethere’s plenty kool aid go aroundno n… gop … think kelly bundy would go joe would match made i… likely plan stands bilked many islamicists 4 5 wives… absolutely quebec also starts letter q coincidence nope pam follower christ liking post two hypocrites bull  china amp worthless dems created economy look forward planting biden2020 lawn sign arrives week first one ive e… look mirror hypocrite go impeach moscowmitch traitor … thinks he’s easily forget disrespect reporter showed  office deserves respect whethe… trumps smoke mirrors bullshit orange conman go… chops eat babies drink alot kind think might night dnc convention would hilarious payroll tax cuts   people employed  😷💔🇺🇸day 1297 trump’s dereliction duty usa notice riots conveniently began lockdowns obama used th… again🤔 gop … american people know president trump makes america1st and… us indeed hopefully large number sturgis idiots die way home infect friends parents ba… ❤️ america god bless america god bless potus 45 sir nothing fo with… b g journalism dead buried counting pens beastsystems … power close  also tell boss gsoros well coming him… since sparky debate skills doesnt read data ue stats hsg costs science covid 19  ci… trouble  dont want cdc nih latethe world see drumpfs covidcoverup predictable wou… potus aka village idiot 4 empty executive orders see it’s joke you’re gonna owe deferred payroll taxes doe… don’t know “nontrafficki…'

# %%
wordcloud = WordCloud(width=1024, height=800, background_color='black', min_font_size= 14).generate(text)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 8), facecolor='black')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)

plt.show()
